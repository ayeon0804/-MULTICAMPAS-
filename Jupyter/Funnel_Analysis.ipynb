# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-paper')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <img src="logic_tree_fun.png" width="500">

# %% [markdown]
# ## __1. 데이터 준비__

# %% [markdown]
# ### _1.1 File Info_
# - 문서 앱내 사용시 발생하는 클라이언 로그 데이터 (after parsed)
# - 서버로그와 달리, 유저의 행동이 발생할 경우 로그 수집 (유저 행동 패턴 파악에 용이)
#     - 클라이언트(앱) 로그
#     - 서버 로그

# %%
df = pd.read_csv('df_funnel.csv', index_col=0)
df.tail(3)
# Out:
#        actiontype ismydoc   ext                         sessionid  \
# 301858      RESET    View  DOCX  41b8c1df291edd2aec30fc610e5b676e
# 301859       OPEN  NoView   PPT  9b5ee236571c2fcbe25132b6ba71d764
# 301860      CLOSE  NoView   PPT  9b5ee236571c2fcbe25132b6ba71d764
#
#        documentposition   datetime screen
# 301858         OTHERAPP   2016.7.5   Main
# 301859         OTHERAPP  2016.7.14   Main
# 301860         OTHERAPP  2016.7.14   Main

# %% [markdown]
# ### _1.2 Columns Info_
# - actiontype: 문서 이용시 행동(OPEN, CLOSE, SAVE,,)
# - ismydoc: 내문서 해당 여부(중요x)
# - ext: 문서 확장자
# - sessionid: 유저 식별자
# - documentposition: 문서 이용시 위치 정보(CLOUD, OTHERAPP)
# - datetime: Timestamp
# - screen: 앱내 화면 이름

# %%
display(df.actiontype.unique())
display(df.ismydoc.unique())
display(df.ext.unique())
display(df.documentposition.unique()) # NONE 데이터 존재
display(df.screen.unique())
# Out:
# array(['OPEN', 'CLOSE', 'RESET', 'SAVEAS', 'SAVE', 'SAVEAS_OTHER',
#        'EXPORT_SAME', 'EXPORT'], dtype=object)
# array(['NoView', 'View'], dtype=object)
# array(['PDF', 'HWP', 'XLSX', 'PPT', 'DOCX', 'ODT', 'DOC', 'XLS', 'PPTX',
#        'TXT', 'PPS', 'PPSX', 'WORD', 'PNG', 'JPG', 'SHEET'], dtype=object)
# array(['LOCALSTORAGE', 'MYPOLARISDRIVE', 'OTHERAPP', 'NEWDOCUMENT',
#        'NONE', 'OTHERCLOUD', 'SHAREDDOCUMENT'], dtype=object)
# array(['Per_Dir', 'Pub_Dir', 'Main', 'InProduct_Web', 'InProduct_Mob',
#        'Purchase_page', 'Purchase_done'], dtype=object)

# %% [markdown]
# ## 2. 전처리

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 301861 entries, 0 to 301860
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   actiontype        301861 non-null  object
#  1   ismydoc           301861 non-null  object
#  2   ext               301861 non-null  object
#  3   sessionid         301861 non-null  object
#  4   documentposition  301861 non-null  object
#  5   datetime          301861 non-null  object
#  6   screen            301861 non-null  object
# dtypes: object(7)
# memory usage: 18.4+ MB

# %%
df.datetime = df.datetime.astype('datetime64[ns]')
df.tail()
# Out:
#        actiontype ismydoc   ext                         sessionid  \
# 301856      CLOSE    View  XLSX  2ed068d5e6a72e80e4a997c01c59f782
# 301857       OPEN  NoView  DOCX  41b8c1df291edd2aec30fc610e5b676e
# 301858      RESET    View  DOCX  41b8c1df291edd2aec30fc610e5b676e
# 301859       OPEN  NoView   PPT  9b5ee236571c2fcbe25132b6ba71d764
# 301860      CLOSE  NoView   PPT  9b5ee236571c2fcbe25132b6ba71d764
#
#        documentposition   datetime screen
# 301856         OTHERAPP 2016-07-07   Main
# 301857         OTHERAPP 2016-07-05   Main
# 301858         OTHERAPP 2016-07-05   Main
# 301859         OTHERAPP 2016-07-14   Main
# 301860         OTHERAPP 2016-07-14   Main

# %%
display(df.datetime.dt.year[:5])
display(df.datetime.dt.month[:5])
display(df.datetime.dt.day[:5])
# Out:
# 0    2016
# 1    2016
# 2    2016
# 3    2016
# 4    2016
# Name: datetime, dtype: int64
# 0    7
# 1    7
# 2    7
# 3    7
# 4    7
# Name: datetime, dtype: int64
# 0    18
# 1    18
# 2    18
# 3    18
# 4     6
# Name: datetime, dtype: int64

# %% [markdown]
# ### _2.1 결측치 처리_

# %%
df.isnull().sum()
# Out:
# actiontype          0
# ismydoc             0
# ext                 0
# sessionid           0
# documentposition    0
# datetime            0
# screen              0
# dtype: int64

# %%
df_by_screen = df.groupby(['datetime','screen'])['sessionid'].nunique().unstack()
df_by_screen
# Out:
# screen     InProduct_Mob  InProduct_Web    Main  Per_Dir  Pub_Dir  \
# datetime
# 2016.7.1           137.0          147.0  3582.0    296.0   1008.0
# 2016.7.10           62.0          122.0  1872.0    230.0    636.0
# 2016.7.11          125.0          139.0  2944.0    332.0    801.0
# 2016.7.12          138.0          157.0  3646.0    371.0   1000.0
# 2016.7.13          132.0          172.0  3544.0    334.0    988.0
# 2016.7.14          131.0          153.0  3479.0    364.0    923.0
# 2016.7.15           95.0          147.0  3281.0    320.0    875.0
# 2016.7.16           91.0          145.0  2483.0    248.0    716.0
# 2016.7.17           75.0          134.0  1903.0    277.0    696.0
# 2016.7.18          133.0          162.0  2882.0    317.0    841.0
# 2016.7.19          124.0          137.0  3552.0    331.0    934.0
# 2016.7.2            89.0          124.0  2683.0    206.0    801.0
# 2016.7.20          120.0          161.0  3588.0    393.0    934.0
# 2016.7.21          103.0          150.0  3452.0    379.0    951.0
# 2016.7.22          136.0          143.0  3348.0    334.0    929.0
# 2016.7.23           85.0          108.0  2522.0    244.0    692.0
# 2016.7.24           84.0          132.0  1903.0    236.0    638.0
# 2016.7.25          117.0          140.0  2923.0    388.0    837.0
# 2016.7.26          141.0          171.0  3567.0    405.0   1010.0
# 2016.7.27          107.0          169.0  3486.0    396.0    925.0
# 2016.7.28          126.0          131.0  3375.0    369.0    949.0
# 2016.7.29          104.0          123.0  3192.0    362.0    912.0
# 2016.7.3            50.0           83.0  1886.0    165.0    590.0
# 2016.7.30           74.0          103.0  2433.0    212.0    730.0
# 2016.7.4           112.0          104.0  2808.0    281.0    764.0
# 2016.7.5           118.0          138.0  3335.0    300.0    842.0
# 2016.7.6           138.0          145.0  3256.0    293.0    855.0
# 2016.7.7           110.0          117.0  3150.0    266.0    807.0
# 2016.7.8           117.0          148.0  3208.0    273.0    865.0
# 2016.7.9           102.0          138.0  2381.0    229.0    748.0
#
# screen     Purchase_done  Purchase_page
# datetime
# 2016.7.1             2.0           23.0
# 2016.7.10            2.0           18.0
# 2016.7.11            NaN           26.0
# 2016.7.12            4.0           26.0
# 2016.7.13            1.0           35.0
# 2016.7.14            5.0           16.0
# 2016.7.15            2.0           22.0
# 2016.7.16            1.0           22.0
# 2016.7.17            3.0           20.0
# 2016.7.18            NaN           30.0
# 2016.7.19            NaN           24.0
# 2016.7.2             2.0           15.0
# 2016.7.20            6.0           31.0
# 2016.7.21            1.0           22.0
# 2016.7.22            2.0           28.0
# 2016.7.23            1.0           24.0
# 2016.7.24            3.0           24.0
# 2016.7.25            2.0           26.0
# 2016.7.26            3.0           33.0
# 2016.7.27            1.0           30.0
# 2016.7.28            3.0           30.0
# 2016.7.29            2.0           23.0
# 2016.7.3             NaN           28.0
# 2016.7.30            1.0           14.0
# 2016.7.4             NaN           29.0
# 2016.7.5             1.0           26.0
# 2016.7.6             1.0           30.0
# 2016.7.7             NaN           18.0
# 2016.7.8             2.0           20.0
# 2016.7.9             2.0           23.0

# %%
df_by_screen.isnull().sum()
# Out:
# screen
# InProduct_Mob    0
# InProduct_Web    0
# Main             0
# Per_Dir          0
# Pub_Dir          0
# Purchase_done    6
# Purchase_page    0
# dtype: int64

# %%
df_by_screen.fillna(0, inplace=True)
df_by_screen
# Out:
# screen      InProduct_Mob  InProduct_Web    Main  Per_Dir  Pub_Dir  \
# datetime
# 2016-07-01          137.0          147.0  3582.0    296.0   1008.0
# 2016-07-02           89.0          124.0  2683.0    206.0    801.0
# 2016-07-03           50.0           83.0  1886.0    165.0    590.0
# 2016-07-04          112.0          104.0  2808.0    281.0    764.0
# 2016-07-05          118.0          138.0  3335.0    300.0    842.0
# 2016-07-06          138.0          145.0  3256.0    293.0    855.0
# 2016-07-07          110.0          117.0  3150.0    266.0    807.0
# 2016-07-08          117.0          148.0  3208.0    273.0    865.0
# 2016-07-09          102.0          138.0  2381.0    229.0    748.0
# 2016-07-10           62.0          122.0  1872.0    230.0    636.0
# 2016-07-11          125.0          139.0  2944.0    332.0    801.0
# 2016-07-12          138.0          157.0  3646.0    371.0   1000.0
# 2016-07-13          132.0          172.0  3544.0    334.0    988.0
# 2016-07-14          131.0          153.0  3479.0    364.0    923.0
# 2016-07-15           95.0          147.0  3281.0    320.0    875.0
# 2016-07-16           91.0          145.0  2483.0    248.0    716.0
# 2016-07-17           75.0          134.0  1903.0    277.0    696.0
# 2016-07-18          133.0          162.0  2882.0    317.0    841.0
# 2016-07-19          124.0          137.0  3552.0    331.0    934.0
# 2016-07-20          120.0          161.0  3588.0    393.0    934.0
# 2016-07-21          103.0          150.0  3452.0    379.0    951.0
# 2016-07-22          136.0          143.0  3348.0    334.0    929.0
# 2016-07-23           85.0          108.0  2522.0    244.0    692.0
# 2016-07-24           84.0          132.0  1903.0    236.0    638.0
# 2016-07-25          117.0          140.0  2923.0    388.0    837.0
# 2016-07-26          141.0          171.0  3567.0    405.0   1010.0
# 2016-07-27          107.0          169.0  3486.0    396.0    925.0
# 2016-07-28          126.0          131.0  3375.0    369.0    949.0
# 2016-07-29          104.0          123.0  3192.0    362.0    912.0
# 2016-07-30           74.0          103.0  2433.0    212.0    730.0
#
# screen      Purchase_done  Purchase_page
# datetime
# 2016-07-01            2.0           23.0
# 2016-07-02            2.0           15.0
# 2016-07-03            0.0           28.0
# 2016-07-04            0.0           29.0
# 2016-07-05            1.0           26.0
# 2016-07-06            1.0           30.0
# 2016-07-07            0.0           18.0
# 2016-07-08            2.0           20.0
# 2016-07-09            2.0           23.0
# 2016-07-10            2.0           18.0
# 2016-07-11            0.0           26.0
# 2016-07-12            4.0           26.0
# 2016-07-13            1.0           35.0
# 2016-07-14            5.0           16.0
# 2016-07-15            2.0           22.0
# 2016-07-16            1.0           22.0
# 2016-07-17            3.0           20.0
# 2016-07-18            0.0           30.0
# 2016-07-19            0.0           24.0
# 2016-07-20            6.0           31.0
# 2016-07-21            1.0           22.0
# 2016-07-22            2.0           28.0
# 2016-07-23            1.0           24.0
# 2016-07-24            3.0           24.0
# 2016-07-25            2.0           26.0
# 2016-07-26            3.0           33.0
# 2016-07-27            1.0           30.0
# 2016-07-28            3.0           30.0
# 2016-07-29            2.0           23.0
# 2016-07-30            1.0           14.0

# %%
x = df[['actiontype','ismydoc','ext','screen']]
y = df[['documentposition']]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

X = x.apply(lambda x : encoder.fit_transform(x))
y = y.apply(lambda y : encoder.fit_transform(y))

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=10) # test_size = 0.3

# %%
x.shape, y.shape, x_train.shape, x_test.shape
# Out:
# ((301861, 4), (301861, 1), (226395, 4), (75466, 4))

# %%
df.ext.unique()
# Out:
# array(['PDF', 'HWP', 'XLSX', 'PPT', 'DOCX', 'ODT', 'DOC', 'XLS', 'PPTX',
#        'TXT', 'PPS', 'PPSX', 'WORD', 'PNG', 'JPG', 'SHEET'], dtype=object)

# %%
ext_change = {'XLSX':'XLS', 'DOCX':'DOC', 'PPTX':'PPT', 'PPS':'PPT', 'PPSX':'PPT', 'ODT':'TXT', 'PNG':'JPG'}

df.ext.replace(ext_change, inplace=True)
df.ext.unique()
# Out:
# array(['PDF', 'HWP', 'XLS', 'PPT', 'DOC', 'TXT', 'WORD', 'JPG', 'SHEET'],
#       dtype=object)

# %%
result = []
j = 0
for i in range(len(df)-1):
    if df.sessionid[i] == df.sessionid[i+1]:
        result.append(j)
        if i == (len(df)-2):
            result.append(j)
    else:
        result.append(j)
        j += 1
        if i == (len(df)-2):
            result.append(j)

# %%
result[-10:]
# Out:
# [132149,
#  132149,
#  132150,
#  132150,
#  132151,
#  132151,
#  132152,
#  132152,
#  132153,
#  132153]

# %%
df['id'] = pd.Series(result)
df.tail()
# Out:
#        actiontype ismydoc  ext                         sessionid  \
# 301856      CLOSE    View  XLS  2ed068d5e6a72e80e4a997c01c59f782
# 301857       OPEN  NoView  DOC  41b8c1df291edd2aec30fc610e5b676e
# 301858      RESET    View  DOC  41b8c1df291edd2aec30fc610e5b676e
# 301859       OPEN  NoView  PPT  9b5ee236571c2fcbe25132b6ba71d764
# 301860      CLOSE  NoView  PPT  9b5ee236571c2fcbe25132b6ba71d764
#
#        documentposition   datetime screen      id
# 301856         OTHERAPP   2016.7.7   Main  132151
# 301857         OTHERAPP   2016.7.5   Main  132152
# 301858         OTHERAPP   2016.7.5   Main  132152
# 301859         OTHERAPP  2016.7.14   Main  132153
# 301860         OTHERAPP  2016.7.14   Main  132153

# %%
col = list(df.columns)
col.remove('datetime')
col.remove('id')
col
# Out:
# ['actiontype', 'ismydoc', 'ext', 'sessionid', 'documentposition', 'screen']

# %%
df[col] = df[col].applymap(lambda x : x.upper())
df
# Out:
#        actiontype ismydoc  ext                         sessionid  \
# 0            OPEN  NOVIEW  PDF  9400FD2E43D7DC2D054CA78806236EE1
# 1           CLOSE  NOVIEW  PDF  9400FD2E43D7DC2D054CA78806236EE1
# 2            OPEN    VIEW  PDF  9400FD2E43D7DC2D054CA78806236EE1
# 3           CLOSE    VIEW  PDF  9400FD2E43D7DC2D054CA78806236EE1
# 4            OPEN  NOVIEW  PDF  F191063C562691041DFA935FF0876975
# ...           ...     ...  ...                               ...
# 301856      CLOSE    VIEW  XLS  2ED068D5E6A72E80E4A997C01C59F782
# 301857       OPEN  NOVIEW  DOC  41B8C1DF291EDD2AEC30FC610E5B676E
# 301858      RESET    VIEW  DOC  41B8C1DF291EDD2AEC30FC610E5B676E
# 301859       OPEN  NOVIEW  PPT  9B5EE236571C2FCBE25132B6BA71D764
# 301860      CLOSE  NOVIEW  PPT  9B5EE236571C2FCBE25132B6BA71D764
#
#        documentposition   datetime   screen      id
# 0          LOCALSTORAGE  2016.7.18  PER_DIR       0
# 1          LOCALSTORAGE  2016.7.18  PER_DIR       0
# 2        MYPOLARISDRIVE  2016.7.18  PUB_DIR       0
# 3        MYPOLARISDRIVE  2016.7.18  PUB_DIR       0
# 4              OTHERAPP   2016.7.6     MAIN       1
# ...                 ...        ...      ...     ...
# 301856         OTHERAPP   2016.7.7     MAIN  132151
# 301857         OTHERAPP   2016.7.5     MAIN  132152
# 301858         OTHERAPP   2016.7.5     MAIN  132152
# 301859         OTHERAPP  2016.7.14     MAIN  132153
# 301860         OTHERAPP  2016.7.14     MAIN  132153
#
# [301861 rows x 8 columns]
